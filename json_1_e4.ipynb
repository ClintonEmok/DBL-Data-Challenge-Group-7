# %%
import numpy as np
import json as json
import pandas as pd
from pandas.io.json import json_normalize

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.0f' % x)
#This removes the scientific notation in columns like 'id'
df = pd.read_json('C:/Users/20213027/PycharmProjects/airlineproject/airlines_1_1.json', lines=True)
df_main = df.drop(df[df.lang != 'en'].index)
df_main
# Out:
#                      created_at                  id              id_str  \
# 1     2019-05-22 12:20:01+00:00 1131172864147808256 1131172864147808256
# 3     2019-05-22 12:20:12+00:00 1131172909463027712 1131172909463027712
# 4     2019-05-22 12:20:28+00:00 1131172975682605056 1131172975682605056
# 5     2019-05-22 12:20:36+00:00 1131173010235375616 1131173010235375616
# 6     2019-05-22 12:20:36+00:00 1131173010508062720 1131173010508062720
# ...                         ...                 ...                 ...
# 14384 2019-05-23 11:42:26+00:00 1131525791429402624 1131525791429402624
# 14385 2019-05-23 11:42:27+00:00 1131525795804045312 1131525795804045312
# 14386 2019-05-23 11:42:27+00:00 1131525797313949696 1131525797313949696
# 14387 2019-05-23 11:42:35+00:00 1131525832500031488 1131525832500031488
# 14388 2019-05-23 11:42:44+00:00 1131525868495474688 1131525868495474688
#
#                                                     text display_text_range  \
# ...

# %%
user_df = df_main['user'].apply(pd.Series)
user_df
# Out:
#                         id               id_str                 name  \
# 1               3420691215           3420691215             hounddog
# 3                 36488556             36488556           Bar Buzard
# 4                 14193348             14193348         Nimish Gupta
# 5      1025334292166127617  1025334292166127617          AiroLuggage
# 6               1662186764           1662186764   Jings, crivvens...
# ...                    ...                  ...                  ...
# 14384           1499872951           1499872951       Andy Carpenter
# 14385           2182054841           2182054841  Croydon Mums&Babies
# 14386  1000339516203421696  1000339516203421696            Royal Eve
# 14387            128174143            128174143         stuart finch
# 14388           2285714020           2285714020          Dave Cooper
#
#            screen_name         location                             url  \
# ...

# %%
entity_df = df_main['entities'].apply(pd.Series)
entity_df
# Out:
#                                               hashtags  \
# 1                                                   []
# 3                                                   []
# 4                                                   []
# 5      [{'text': 'GoogleAlerts', 'indices': [83, 96]}]
# 6                                                   []
# ...                                                ...
# 14384                                               []
# 14385                                               []
# 14386                                               []
# 14387                                               []
# 14388                                               []
#
#                                                     urls  \
# 1                                                     []
# 3                                                     []
# 4                                                     []
# 5      [{'url': 'https://t.co/SOI36Thhbf', 'expanded_...
# ...

# %%
len(df_main['created_at'])
# Out:
# 11228

# %%
ax = df_main['reply_count'].plot();
df_main['retweet_count'].plot(ax=ax);
df_main['favorite_count'].plot(ax=ax);

# %%
text_list = df_main['text'].tolist()
text_list
Bal_list = [t for t in text_list if 'British Airways' in t] + [y for y in text_list if 'British_Airways' in y]
nRT_Bal_list = [u for u in Bal_list if 'RT' not in u]
nRT_Bal_list
KLM_list = [i for i in text_list if 'KLM' in i]
nRT_KLM_list = [o for o in KLM_list if 'RT' not in o]
nRT_KLM_list
AAl_list = [t for t in text_list if 'American Airlines' in t] + [y for y in text_list if 'AmericanAir' in y]
nRT_AAl_list = [u for u in AAl_list if 'RT' not in u]
nRT_AAl_list
print('KLM', len(nRT_KLM_list), 'B-airlines', len(nRT_Bal_list), 'A-airlines', len(nRT_AAl_list))
# Out:
# KLM 243 B-airlines 971 A-airlines 1500

# %%
pd.reset_option('display.float_format')
#Reset back to default as the change in the first code block is a global jupyter change
